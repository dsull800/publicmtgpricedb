# %%
import pymysql #not needed
import psycopg2

from itertools import chain
import numpy as np
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import requests 
from datetime import datetime
import re
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
conn = psycopg2.connect(redacted)

# %%
cur=conn.cursor()

# %%
#cur.execute("""SELECT * FROM public.prices WHERE uuid='002ca814-c13f-50ae-a453-5d413b4d0fc4'""")

# %%
#rows=cur.fetchall()

# %%
#cur.execute("""SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica'""")

#cur.execute("""SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica') ORDER BY releasedate""")

#cur.execute('''SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica'))''')

#cur.execute("""SELECT * FROM public.cards WHERE name='Arrest'""")

# %%
#cur.execute('''SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica'))''')

#cur.execute("""SELECT date,price,name,setcode,prices.id,prices.type,prices.uuid FROM public.prices INNER JOIN (SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND ispaper=1 AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica')))as w ON w.uuid=prices.uuid WHERE prices.type='paper' ORDER BY name""")

# %%
# cur.execute("""SELECT COUNT(*) FROM public.prices INNER JOIN (
# SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND ispaper=1 AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica')
# ))as w ON w.uuid=prices.uuid WHERE prices.type='paper'""")




cur.execute('''SELECT name FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica'))''')

# %%
rows=cur.fetchall()

# %%
# print("\nShow me the databases:\n")
# for row in rows:
#     print( "   "+"\n", row)

# %%
cur.close()

# %%
#SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica') ORDER BY releasedate)

# %%
#cur.execute("""SELECT * FROM public.prices INNER JOIN (SELECT * FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica')))as w ON w.uuid=prices.uuid""")

# %%
#https://www.ebay.com/sch/i.html?_nkw=x+y&rt=nc&LH_Sold=1&LH_Complete=1

# %%
rows[1][0]
# Out:
# 'Aethersphere Harvester'

# %%
# SoupArr=[]
# for idx,cardname in enumerate(rows):
#     url=requests.get('https://www.ebay.com/sch/i.html?_nkw='+cardname[0]+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200')
#     SoupArr.append(BeautifulSoup(url.text,'html.parser'))

# %%
SoupArr=[]
url=requests.get('https://www.ebay.com/sch/i.html?_nkw='+'temple garden'+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200&_pgn=1')
SoupArr.append(BeautifulSoup("url.text",'html.parser'))

# %%
print(SoupArr[0].prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
transactions=SoupArr[0].find_all('div',attrs={"class":"s-item__info clearfix"})

# %%
print(transactions)
# Out:
# [<div class="s-item__info clearfix"><div class="s-item__title-hotness"></div><a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi:1686|iid:1|li:7400|luid:1|scen:Listings","parentrq":"b1d4b06f16f0a9e80253b552ffd0aca6","pageci":"97dc7db0-38e4-11ea-9e82-74dbd180595f"}}' href="https://www.ebay.com/itm/2X-Temple-Garden-Return-Guilds-of-Ravnica-X2-Pack-Fresh-FREE-SHIPPING/133302325999?hash=item1f097012ef:g:bOsAAOSwPa9eFpv7"><div style="display:flex;"><div class="s-item__title--tagblock"><span role="text"><span class="s-0cm627">S</span><span class="s-0cm627">o</span><span class="s-6479lsq">C</span><span class="s-6479lsq">5</span><span class="s-0cm627">l</span><span class="s-0cm627">d</span><span class="s-0cm627"> </span><span class="s-6479lsq">W</span><span class="s-6479lsq">3</span><span class="s-0cm627"> </span
# ...

# %%
print(transactions[100])
# Out:
# <div class="s-item__info clearfix"><div class="s-item__title-hotness"></div><a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi:1686|iid:101|li:7400|luid:1|scen:Listings","parentrq":"b1d4b06f16f0a9e80253b552ffd0aca6","pageci":"97dc7db0-38e4-11ea-9e82-74dbd180595f"}}' href="https://www.ebay.com/itm/4x-Temple-Garden-MTG-Guilds-of-Ravnica-NM-Magic-The-Gathering/133280698431?hash=item1f0826103f:g:BmcAAOSwgiVd~mef"><div style="display:flex;"><div class="s-item__title--tagblock"><span role="text"><span class="s-0cm627">S</span><span class="s-6479lsq">9</span><span class="s-0cm627">o</span><span class="s-0cm627">l</span><span class="s-6479lsq">X</span><span class="s-0cm627">d</span><span class="s-6479lsq">I</span><span class="s-6479lsq">Q</span><span class="s-6479lsq">K</span><span class="s-0cm627"> </span><span
# ...

# %%
type(transactions[0])
# Out:
# bs4.element.Tag

# %%
#transactions[0].find_all('h3',attrs={"class":"s-item__title"}).contents

# %%
transactions[0].find_all('span',attrs={"class":"s-item__price"})
# Out:
# [<span class="s-item__price"><span class="POSITIVE">$16.00</span></span>]

# %%
transactions1=SoupArr[0].find_all('span',attrs={"class":"POSITIVE"})

# %%
transactions1
# Out:
# [<span class="POSITIVE">$16.00</span>,
#  <span class="STRIKETHROUGH POSITIVE">$90.00</span>,
#  <span class="POSITIVE">$8.75</span>,
#  <span class="STRIKETHROUGH POSITIVE">$35.00</span>,
#  <span class="POSITIVE">$36.99</span>,
#  <span class="POSITIVE">$11.99</span>,
#  <span class="POSITIVE">$8.00</span>,
#  <span class="POSITIVE">$8.00</span>,
#  <span class="POSITIVE">$6.99</span>,
#  <span class="POSITIVE">$1.80</span>,
#  <span class="POSITIVE">$29.00</span>,
#  <span class="POSITIVE">$30.51</span>,
#  <span class="POSITIVE">$14.00</span>,
#  <span class="POSITIVE">$6.00</span>,
#  <span class="POSITIVE">$28.99</span>,
#  <span class="POSITIVE">$8.00</span>,
#  <span class="POSITIVE">$8.00</span>,
#  <span class="STRIKETHROUGH POSITIVE">$8.12</span>,
#  <span class="POSITIVE">$26.00</span>,
#  <span class="POSITIVE">$4.20</span>,
#  <span class="POSITIVE">$5.00</span>,
#  <span class="POSITIVE">$6.50</span>,
#  <span class="POSITIVE">$6.00</span>,
# ...

# %%
type(transactions1[0])
# Out:
# bs4.element.Tag

# %%
print(transactions1[0].string)
# Out:
# $16.00

# %%
print(transactions1[0].name)
# Out:
# span

# %%
# xfun=lambda x:"x"+str(x)
# funx=lambda x:str(x)+"x"
# titlequantities=list(chain.from_iterable((xfun(x), funx(x)) for x in range(1,11))) #all lowercase
# titlekeywords=["promo","expedition","invocation","invention"]
# titlelanguage=['english','korean','japanese','chinese','russian','spanish']
# titleconditions=['NM','LP','MP','HP','Mint','Lightly Played','Moderately Played','Heavily Played']

# for transaction in transactions:
#     title=transaction.find_all('h3',attrs={"class":"s-item__title"}).string
#     price=transaction.find_all('span',attrs={"class":"POSITIVE"}).string
#     positiveprice=str(transaction.find_all('span',attrs={"class":"POSITIVE"}))
    
#     if positiveprice.find('class="POSITIVE"')!=-1:
#         saletype='normal'
#     elif positiveprice.find('class="POSITIVE ITALIC"')!=-1:
#         saletype='italic'
#     else:
#         saletype='BO accepted'
        
#     for quantity in titlequantities:
#         if title.lower().find(quantity):
#             cardquantity=quantity
#             break
    
#     IsFoil=title.lower().find("foil")!=-1
    
#     for keyword in titlekeywords:
#         if title.lower().find(keyword)!=-1:
#             cardspecial=keyword
#             break
            
#     for language in titlelanguages:
#         if title.lower().find(langauge):
#             cardlanguage=langauge
#             break
            
#     for condition in titleconditions:
#         if title.lower().find(condition):
#             cardcondition=condition
#             break
    
#         datestring=''
#     for dateitem in range(6,len(transactions[100].find_all('span',attrs={"class":"s-39tvjn"}))):
#         datestring=datestring+transactions[100].find_all('span',attrs={"class":"s-39tvjn"})[dateitem].string
#         realdate=datetime.strptime(datestring,'%b %d, %Y')

# %%
transactions[0].find_all('span',attrs={"role":"text"})
# Out:
# [<span role="text"><span class="s-0cm627">S</span><span class="s-0cm627">o</span><span class="s-6479lsq">C</span><span class="s-6479lsq">5</span><span class="s-0cm627">l</span><span class="s-0cm627">d</span><span class="s-0cm627"> </span><span class="s-6479lsq">W</span><span class="s-6479lsq">3</span><span class="s-0cm627"> </span><span class="s-6479lsq">Z</span><span class="s-0cm627">J</span><span class="s-0cm627">a</span><span class="s-6479lsq">Q</span><span class="s-0cm627">n</span><span class="s-0cm627"> </span><span class="s-0cm627">1</span><span class="s-6479lsq">2</span><span class="s-6479lsq">M</span><span class="s-0cm627">5</span><span class="s-0cm627">,</span><span class="s-0cm627"> </span><span class="s-0cm627">2</span><span class="s-0cm627">0</span><span class="s-6479lsq">5</span><span class="s-0cm627">2</span><span class="s-0cm627">0</span><span class="s-6479lsq">K</span></span>]

# %%
# s-item__ended-date s-item__endedDate

transactions[0].find_all('span',attrs={"class":"s-item__ended-date s-item__endedDate"})[0].string
# Out:
# 'Jan-15 22:51'

# %%
datedate=datetime.strptime(transactions[0].find_all('span',attrs={"class":"s-item__ended-date s-item__endedDate"})[0].string,'%b-%d %H:%M')
print(datedate.month)

if datedate.month>=2:
    datedate=datedate.replace(year=2019)
else:
    datedate=datedate.replace(year=2020)
    
print(datedate)
# Out:
# 1
# 2020-01-15 22:51:00

# %%
datestring=''
for dateitem in range(6,len(transactions[100].find_all('span',attrs={"class":"s-39tvjn"}))):
    datestring=datestring+transactions[100].find_all('span',attrs={"class":"s-39tvjn"})[dateitem].string
print(datestring)
realdate=datetime.strptime(datestring,'%b %d, %Y')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-34-96ed11ffea0f> in <module>
#       4     datestring=datestring+transactions[100].find_all('span',attrs={"class":"s-39tvjn"})[dateitem].string
#       5 print(datestring)
# ----> 6 realdate=datetime.strptime(datestring,'%b %d, %Y')
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /opt/conda/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
# ...

# %%
xfun=lambda x:"x"+str(x)
funx=lambda x:str(x)+"x"
titlequantities=list(chain.from_iterable((xfun(x), funx(x)) for x in range(1,11))) #all lowercase, g(x)) for x in range(1,11)))

# %%
print(titlequantities)

# %%
IsFoil=title.lower().find("foil")!=-1

# %%
len(SoupArr[0].find_all('li',attrs={"class":"x-pagination__li"}))
# Out:
# 3

# %%
url=requests.get('https://www.ebay.com/sch/i.html?_nkw='+"cardname[0]"+
                         '&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200&_pgn='+str(1))

# %%
cur.close()
conn.close()

# %%
totalpagenum=len(SoupArr[0].find_all('li',attrs={"class":"x-pagination__li"}))

# %%
totalpagenum

# %%
BeautifulSoup('''<td><input type="checkbox" name="deck_check[25]" value="1" checked=""><input type="hidden" name="deck_ref[25]" value="369515"></td>
		  <td class="S11"><a href="event?e=24281&amp;d=369515&amp;f=PI">Red Deck Wins</a></td>
		  <td class="G11"><a class="player" href="search?player=Dylan+Hand">Dylan Hand</a></td>
		  <td class="S10"><a href="event?e=24281&amp;f=PI">Star City Games Classic @ Knoxville</a></td>
		  <td class="O16" align="center"><img src="graph/star.png"><img src="graph/star.png"></td>
		  <td class="S11" align="center">5-8</td>
		  <td class="S10">12/01/20</td>''','html.parser')
# Out:
# <td><input checked="" name="deck_check[25]" type="checkbox" value="1"/><input name="deck_ref[25]" type="hidden" value="369515"/></td>
# <td class="S11"><a href="event?e=24281&amp;d=369515&amp;f=PI">Red Deck Wins</a></td>
# <td class="G11"><a class="player" href="search?player=Dylan+Hand">Dylan Hand</a></td>
# <td class="S10"><a href="event?e=24281&amp;f=PI">Star City Games Classic @ Knoxville</a></td>
# <td align="center" class="O16"><img src="graph/star.png"/><img src="graph/star.png"/></td>
# <td align="center" class="S11">5-8</td>
# <td class="S10">12/01/20</td>
