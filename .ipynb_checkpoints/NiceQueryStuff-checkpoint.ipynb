# %%
import psycopg2

from itertools import chain
import numpy as np
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import requests 
from datetime import datetime
import re
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
conn = psycopg2.connect(redacted)

# %%
cur=conn.cursor()

# %%
cur.execute('''SELECT name FROM public.cards WHERE rarity IN('mythic','rare') AND setcode IN(SELECT code FROM public.sets WHERE type='expansion' and releasedate>=(SELECT releasedate FROM public.sets WHERE mcmname='Return to Ravnica'))''')

# %%
completedcards=set([('Rix Maadi Reveler',),
("Burning Sun's Avatar",),
('Torbran, Thane of Red Fell',),
('Possibility Storm',),
('Tezzeret, Master of Metal',),
('Growing Rites of Itlimoc',),
('Grasping Current',),
('Needle Spires',),
('Adorned Pouncer',),
('Botanical Sanctum',),
('Narcomoeba',),
('Temple Altisaur',),
('Noxious Gearhulk',),
('Entrancing Melody',),
('Deeproot Champion',),
('Master Trinketeer',),
('Twinflame',),
('Woodland Cemetery',),
('King Macar, the Gold-Cursed',),
('Inexorable Blob',),
('Nissa, Voice of Zendikar',),
('Aetherworks Marvel',),
('The Scorpion God',),
('Palisade Giant',),
('Medomai the Ageless',),
('Werewolf of Ancient Hunger',),
('Hanweir Battlements',),
('World Shaper',),
('Harmless Offering',),
('Cabal Stronghold',),
('Dreadbore',),
('Opportunistic Dragon',),
('Ammit Eternal',),
('Crucible of the Spirit Dragon',),
("Vanquisher's Banner",),
('Dance of the Manse',),
('Ghostfire Blade',),
("Lich's Mastery",),
('Precognition Field',),
("Ral's Dispersal",),
('Hour of Glory',),
('Hostage Taker',),
('Nissa, Who Shakes the World',),
('Steel Leaf Champion',),
('Master of Waves',),
('Treasury Thrull',),
('Driven',),
('Gutterbones',),
('Castle Embereth',),
("Assassin's Trophy",),
('Ephara, God of the Polis',),
('Sanctum of Ugin',),
('Shadowed Caravel',),
('Feasting Troll King',),
('Whip of Erebos',),
('Temple of Triumph',),
('Watery Grave',),
("Kamahl's Druidic Vow",),
('The First Eruption',),
('Bring to Light',),
('Revenge',),
('Jhoira, Weatherlight Captain',),
('Hushbringer',),
('Inspiring Vantage',),
('Blooming Marsh',),
('Chittering Witch',),
('Entering',),
('Launch the Fleet',),
('Ivorytusk Fortress',),
('Invocation of Saint Traft',),
('Wooded Foothills',),
('Ooze Flux',),
('Rakshasa Vizier',),
('Hallowed Fountain',),
('Kiora, the Crashing Wave',),
('Fae of Wishes',),
('Dictate of Erebos',),
('Sundering Stroke',),
('Tree of Perdition',),
('Risk Factor',),
('Dovin Baan',),
('Glyph Keeper',),
('Search for Azcanta',),
('Kopala, Warden of Waves',),
('Stomping Ground',),
('Assemble',),
('Unesh, Criosphinx Sovereign',),
('Arlinn Kord',),
('Thran Temporal Gateway',),
('Drana, Liberator of Malakir',),
('Spell Queller',),
('Chance for Glory',),
("Gishath, Sun's Avatar",),
('Thorn Mammoth',),
('Underworld Cerberus',),
('Captured by the Consulate',),
('Collective Defiance',),
('Windswept Heath',),
('Lord of the Void',),
('Vraska, Relic Seeker',),
('Search the City',),
('Rally the Ancestors',),
('Prognostic Sphinx',),
('Shipbreaker Kraken',),
('Banish into Fable',),
('Lyra Dawnbringer',),
('Wandering Fumarole',),
('Immortal Servitude',),
('Goldnight Castigator',),
('Fires of Invention',),
('Helm of the Host',),
('Deathbringer Regent',),
('Huatli, Dinosaur Knight',),
('Cooperate',),
('Ghalta, Primal Hunger',),
('Glint-Sleeve Siphoner',),
('Falkenrath Gorger',),
('Sidisi, Brood Tyrant',),
("Sram's Expertise",),
('Roalesk, Apex Hybrid',),
('Ribbons',),
("Merchant's Dockhand",),
('Naban, Dean of Iteration',),
('Gideon, Ally of Zendikar',),
('Desolation Twin',),
('Planewide Celebration',),
('Sword-Point Diplomacy',),
('General Tazri',),
('Dictate of Kruphix',),
('Bomat Courier',),
('Dark Salvation',),
('Castle Ardenvale',),
('Dread Shade',),
('Timestream Navigator',),
('Goblin Chainwhirler',),
('Jace, Ingenious Mind-Mage',),
('Crush of Tentacles',),
('Aethersquall Ancient',),
('Ogre Slumlord',),
('Port Town',),
('Captivating Crew',),
('Rakdos, Lord of Riots',),
('Ash Zealot',),
("Arguel's Blood Fast",),
('Niv-Mizzet Reborn',),
('Vona, Butcher of Magan',),
('Spark Trooper',),
('Supreme Verdict',),
('Advent of the Wurm',),
("Saheeli's Artistry",),
('Greenwheel Liberator',),
('The Mirari Conjecture',),
("Silumgar's Command",),
('Oath of Ajani',),
('Awaken the Erstwhile',),
('Mausoleum Secrets',),
('Glacial Fortress',),
('Walking Ballista',),
('Azcanta, the Sunken Ruin',),
('Plasm Capture',),
('Gisa and Geralf',),
('Spark Double',),
('The Circle of Loyalty',),
('Eldritch Evolution',),
('Bearer of the Heavens',),
('Alela, Artful Provocateur',),
('Light of the Legion',),
('Sultai Ascendancy',),
('Bounty of Might',),
('The Mending of Dominaria',),
('Utvara Hellkite',),
('Anointed Procession',),
('Call',),
('Thrash',),
('Rest in Peace',),
('Altar of the Brood',),
('Profane Procession',),
('Finale of Promise',),
('Mavren Fein, Dusk Apostle',),
('Release',),
('Noyan Dar, Roil Shaper',),
('Martial Law',),
('Clever Impersonator',),
('Emrakul, the Promised End',),
('Call for Unity',),
('Nissa, Vital Force',),
('Gild',),
('Combat Celebrant',),
('Mogis, God of Slaughter',),
("Firemind's Foresight",),
("Biomancer's Familiar",),
('Scourge of Fleets',),
('Cryptborn Horror',),
('Gruesome Menagerie',),
('Verdant Force',),
('Arashin Sovereign',),
('Temmet, Vizier of Naktamun',),
('Providence',),
('Tireless Tracker',),
('Render Silent',),
('Demon of Dark Schemes',),
('Atarka, World Render',),
('Response',),
('The Immortal Sun',),
("Nahiri's Wrath",),
('Luminate Primordial',),
('Ayara, First of Locthwain',),
('Arashin Foremost',),
('Ormendahl, Profane Prince',),
('Twilight Prophet',),
('The Magic Mirror',),
('Earthshaker Khenra',),
('Axis of Mortality',),
('Identity Thief',),
('Ashcloud Phoenix',),
("Shapers' Sanctuary",),
("Thalia's Lieutenant",),
('Pelt Collector',),
('Irencrag Feat',),
('Illusory Gains',),
("Nissa, Nature's Artisan",),
('Swarm Intelligence',),
('Emmara, Soul of the Accord',),
('Crested Sunmare',),
('Ajani, Valiant Protector',),
('Olivia, Mobilized for War',),
('Deepfathom Skulker',),
('Blood Baron of Vizkopa',),
('Brutal Expulsion',),
('Scrap Trawler',),
('Indomitable Creativity',),
('Simic Ascendancy',),
('Realmwright',),
('Silence the Believers',),
('Sanguine Sacrament',),
('Ramunap Hydra',),
('Key to the City',),
('Welcome to the Fold',),
("Sigarda's Aid",),
('Triad of Fates',),
('Sanctifier of Souls',),
('Nicol Bolas, God-Pharaoh',),
('Temple of Abandon',),
('Stomp',),
('Elder Deep-Fiend',),
('Enter the Infinite',),
('Warrant',),
('Irrigated Farmland',),
('Counterflux',),
('Hammer of Purphoros',),
('Fblthp, the Lost',),
('Breeding Pool',),
('Slaughter Games',),
('Ral Zarek',),
("Hazoret's Favor",),
('Nykthos, Shrine to Nyx',),
('Sylvan Caryatid',),
('Dusk',),
('Evra, Halcyon Witness',),
('Sphinx of the Final Word',),
('Skarrgan Hellkite',),
('Herald of Torment',),
('Herald of Secret Streams',),
('Jaya Ballard',),
('Once Upon a Time',),
('Oran-Rief Hydra',),
('Mox Amber',),
('Settle the Wreckage',),
('Felhide Spiritbinder',),
('Earth',),
('Melek, Izzet Paragon',),
('Embercleave',),
('Find',),
('Temple of Silence',),
('Pia Nalaar',),
('Midnight Oil',),
('Deliver Unto Evil',),
('Lathnu Hellion',),
("Slayer's Plate",),
('Rowdy Crew',),
("Heart's Desire",),
('Assemble the Legion',),
('Frontier Siege',),
('Sweltering Suns',),
('Chamber Sentry',),
('Grim Flayer',),
('Anafenza, Kin-Tree Spirit',),
('Divine Visitation',),
('Omnispell Adept',),
("Devils' Playground",),
('Feed',),
('Stolen by the Fae',),
('Ulvenwald Hydra',),
('Dust',),
('Fortified Village',),
('Ashiok, Nightmare Weaver',),
('Primal Amulet',),
('Insidious Will',),
('Fervent Champion',),
('Angelic Skirmisher',),
('Mindreaver',),
('Titan of Eternal Fire',),
('Heaven',),
('Biomass Mutation',),
('Immolation Shaman',),
('Smothering Tithe',),
('Demonlord Belzenlok',),
('Ugin, the Ineffable',),
('Repeating Barrage',),
('Champion of Dusk',),
('Sun-Blessed Mount',),
('Resilient Khenra',),
('Dromoka, the Eternal',),
('Mesmerizing Benthid',),
('Catch',),
("Vance's Blasting Cannons",),
('Deploy the Gatewatch',),
('Swan Song',),
("Rishkar's Expertise",),
('Eidolon of Blossoms',),
('Impervious Greatwurm',),
('Rankle, Master of Pranks',),
('Epiphany at the Drownyard',),
("Kinjalli's Sunwing",),
('Lavinia of the Tenth',),
('Hissing Quagmire',),
('Abhorrent Overlord',),
('Palace Siege',),
('Ritual of Soot',),
('Nighthowler',),
('Nightveil Specter',),
('Bloodstained Mire',),
("Inventors' Fair",),
('Zegana, Utopian Speaker',),
('Sandsteppe Mastodon',),
('Wasteland Strangler',),
("Nissa's Renewal",),
('Bloodhall Priest',),
("Outlaws' Merriment",),
('Beck',),
('Weatherlight',),
('High Sentinels of Arashin',),
("Emperor's Vanguard",),
("Conqueror's Foothold",),
('Temple of Deceit',),
("Ugin's Nexus",),
('Hero of Leina Tower',),
('Hall of Triumph',),
('Emry, Lurker of the Loch',),
("Heron's Grace Champion",),
('Eidolon of the Great Revel',),
('Greenwarden of Murasa',),
('Hero of Goma Fada',),
('Mantis Rider',),
("Gonti's Aether Heart",),
('Dictate of the Twin Gods',),
('Metallic Mimic',),
('Cryptolith Rite',),
('Tromokratis',),
("Tajic, Legion's Edge",),
("Emrakul's Evangel",),
('Zacama, Primal Calamity',),
('Growth-Chamber Guardian',),
('Drownyard Temple',),
('Embereth Skyblazer',),
('Assure',),
('Chance',),
('Angel of Invention',),
('Odric, Lunarch Marshal',),
('Aurelia, the Warleader',),
("Bolas's Citadel",),
('Dread Defiler',),
('Smothering Abomination',),
('Nylea, God of the Hunt',),
('Giant Adephage',),
('Return',),
('Animation Module',),
('Dragon Whisperer',),
('Runaway Steam-Kin',),
('Profaner of the Dead',),
('Aetherling',),
('Fathom Fleet Captain',),
('Lumbering Battlement',),
('Tasigur, the Golden Fang',),
('Bloodsoaked Champion',),
('Kefnet the Mindful',),
('Foreboding Ruins',),
('From Beyond',),
('Signal the Clans',),
('Tithe Taker',),
('Sarkhan the Masterless',),
('Daghatar the Adamant',),
("Ojutai's Command",),
('Fall of the Thran',),
('Cryptbreaker',),
('Unmoored Ego',),
('Blood',),
('Mirror Mockery',),
('Tyrant of Valakut',),
("Liliana's Mastery",),
("Oketra's Last Mercy",),
("Kozilek's Return",),
('Myth Realized',),
('Kozilek, the Great Distortion',),
('Domri, Anarch of Bolas',),
('Scavenger Grounds',),
('Chandra, Flamecaller',),
('Righteous Authority',),
('Icefall Regent',),
('Consulate Crackdown',),
('Arch of Orazca',),
('Zendikar Resurgent',),
('Syr Gwyn, Hero of Ashvale',),
('Elusive Tormentor',),
("Tilonalli's Skinshifter",),
('Narset, Enlightened Master',),
('Oko, Thief of Crowns',),
('Grand Warlord Radha',),
('Tocatli Honor Guard',),
("Kaya's Wrath",),
('Mirrorpool',),
("Illusionist's Bracers",),
('Hollow One',),
('Mirrormade',),
('Stoneforge Masterwork',),
('Deceiver of Form',),
('Supplant Form',),
('Golden Guardian',),
('Garruk, Cursed Huntsman',),
('Nicol Bolas, Dragon-God',),
('Chulane, Teller of Tales',),
('Wicked Wolf',),
('Tezzeret the Schemer',),
('Tome of Legends',),
('Niblis of Frost',),
('Polis Crusher',),
("Gideon's Intervention",),
('Trail of Mystery',),
('Whelming Wave',),
('Spawn of Thraxes',),
('Visage of Bolas',),
('Radiant Flames',),
('Chandra, Bold Pyromancer',),
('Remorseless Punishment',),
('Dubious Challenge',),
('Shu Yun, the Silent Tempest',),
('Storm the Vault',),
('Depala, Pilot Exemplar',),
('Arcane Adaptation',),
("Gideon's Resolve",),
('Mnemonic Betrayal',),
('Tomb of the Dusk Rose',),
('Flooded Strand',),
('Volcanic Vision',),
('Prepare',),
('Mass Manipulation',),
('Meandering Towershell',),
('Akroan Horse',),
('Necropolis Fiend',),
('Quarantine Field',),
('Brutal Hordechief',),
('Tome of the Guildpact',),
('Vraska, Golgari Queen',),
('Aetherstorm Roc',),
('Utter End',),
("Aurelia's Fury",),
('Skylasher',),
("Yawgmoth's Vile Offering",),
('Thousand-Year Storm',),
('Bow of Nylea',),
('Temple of Mystery',),
('Revel of the Fallen God',),
('Thief of Sanity',),
('Ob Nixilis Reignited',),
('Eerie Interlude',),
('Wayfaring Temple',),
('Fleetwheel Cruiser',),
('Dictate of Heliod',),
('Mechanized Production',),
("Thalia's Lancers",),
('Clone Legion',),
('Overflowing Insight',),
('Niambi, Faithful Healer',),
('Faerie Formation',),
('Meletis Charlatan',),
('Purphoros, God of the Forge',),
('Diregraf Colossus',),
('Lost Vale',),
('Marionette Master',),
('Scion of Vitu-Ghazi',),
('Soulfire Grand Master',),
('Ral, Caller of Storms',),
('Ankle Shanker',),
('Fated Infatuation',),
('Molten Primordial',),
('Teferi, Hero of Dominaria',),
('Ashes of the Abhorrent',),
('Wrecking Ogre',),
('Reason',),
('Zada, Hedron Grinder',),
('Siege-Gang Commander',),
('Mana Bloom',),
('Soul Diviner',),
('Skarrg Goliath',),
('Arclight Phoenix',),
('Progenitor Mimic',),
('Happily Ever After',),
("God-Pharaoh's Gift",),
('Midnight Entourage',),
('Finale of Devastation',),
('Polukranos, World Eater',),
('Solar Blaze',),
('Fetid Pools',),
('Dragonmaster Outcast',),
('Fateful Showdown',),
('Five-Alarm Fire',),
('Temur Ascendancy',),
('Pride Sovereign',),
("Tilonalli's Summoner",),
('Master of the Feast',),
('Tomb Robber',),
('See the Unwritten',),
('Beastcaller Savant',),
('Saheeli Rai',),
('Clifftop Retreat',),
('Forgotten Creation',),
('Corrupted Crossroads',),
('Fumigate',),
('Lavinia, Azorius Renegade',),
('Butcher of the Horde',),
("Oko's Hospitality",),
('Stonecoil Serpent',),
('Biogenic Ooze',),
('Wild Beastmaster',),
('Chained to the Rocks',),
('Bedlam Reveler',),
('Fabled Passage',),
('Swiftblade Vindicator',),
('Solemnity',),
('Adanto, the First Fort',),
('Murderous Rider',),
('Aethergeode Miner',),
('Mardu Strike Leader',),
('Yasova Dragonclaw',),
('Resurgence',),
('Foe-Razer Regent',),
('Ravnica at War',),
('Archangel Avacyn',),
('Radiant Destiny',),
('Guardian Project',),
('Trostani Discordant',),
("Berserkers' Onslaught",),
('Dawn',),
('Master of Pearls',),
('Distended Mindbender',),
('Verity Circle',),
('Territorial Allosaurus',),
('Spawn of Mayhem',),
('Explosion',),
('Return of the Wildspeaker',),
('Verdant Crescendo',),
('Nicol Bolas, the Deceiver',),
('Pearl Lake Ancient',),
('Piper of the Swarm',),
('Asylum Visitor',),
('Blackblade Reforged',),
('Grave Betrayal',),
('Permeating Mass',),
('Heliod, God of the Sun',),
('Jadelight Ranger',),
('Yorvo, Lord of Garenbrig',),
('Temple of Enlightenment',),
('Tezzeret, Master of the Bridge',),
('Damnable Pact',),
('Dust Stalker',),
('Temple of Aclazotz',),
('Krenko, Tin Street Kingpin',),
('Dread Wanderer',),
('Nissa, Steward of Elements',),
('Deeproot Elite',),
('End Hostilities',),
('Silent Sentinel',),
('Blast Zone',),
('Failure',),
("Vraska's Stoneglare",),
('Metallurgic Summonings',),
('Jeskai Infiltrator',),
('Hour of Promise',),
("Dovin's Dismissal",),
('Voice of Resurgence',),
('Champion of Stray Souls',),
('Ruins of Oran-Rief',),
('Surrak, the Hunt Caller',),
('Teysa, Envoy of Ghosts',),
('Overwhelming Denial',),
('Liberating Combustion',),
('Torrential Gearhulk',),
('Pheres-Band Warchief',),
("Hero's Downfall",),
('Plague Belcher',),
('Dreadhorde Arcanist',),
('Skybind',),
('Brazen Borrower',),
('Rakshasa Deathdealer',),
("Jarad's Orders",),
('Temple of Malice',),
('Finality',),
('Oko, the Trickster',),
('Pyramid of the Pantheon',),
('Fathom Feeder',),
('Arbiter of the Ideal',),
('Bishop of Binding',),
('Casualties of War',),
("Admiral's Order",),
('Lantern Scout',),
('Narset Transcendent',),
('Stromkirk Condemned',),
("Kari Zev's Expertise",),
('Bishop of Rebirth',),
('Ruinous Path',),
('Hinterland Harbor',),
('Naru Meha, Master Wizard',),
("Verdant Sun's Avatar",),
('Wishclaw Talisman',),
('Thunderbreak Regent',),
('Kazarov, Sengir Pureblood',),
('Lazav, Dimir Mastermind',),
('Shadow of the Grave',),
('Veteran Warleader',),
('Mirrorwing Dragon',),
('Lochmere Serpent',),
('Worldspine Wurm',),
("Ugin's Insight",),
('Aegis of the Gods',),
('Kruphix, God of Horizons',),
('Apocalypse Demon',),
('Psychic Intrusion',),
('Jeering Instigator',),
('Steelbane Hydra',),
('Ramunap Excavator',),
('Cinder Glade',),
('Dragonshift',),
('Dreamcaller Siren',),
('Havoc Festival',),
("Trostani, Selesnya's Voice",),
('Tymaret, the Murder King',),
('Aven Mindcensor',),
('Etrata, the Silencer',),
('Carnage Tyrant',),
('Despair',),
('Relentless Dead',),
('Citywide Bust',),
('Neheb, the Worthy',),
('Linden, the Steadfast Queen',),
('Charnel Troll',),
('Ojutai Exemplars',),
('Swift End',),
('Triskaidekaphobia',),
('Fleet Swallower',),
('Isolated Chapel',),
('Monastery Mentor',),
('Frontline Medic',),
('Mardu Ascendancy',),
('Herald of Anguish',),
('Champion of Wits',),
('Kumena, Tyrant of Orazca',),
('Tishana, Voice of Thunder',),
('Collective Blessing',),
('Avacyn, the Purifier',),
('Oath of Teferi',),
('Seasons Past',),
('Hellkite Tyrant',),
('Deathcap Cultivator',),
('Guul Draz Overseer',),
("Heroes' Bane",),
('Worthy Knight',),
('Scatter to the Winds',),
('Gideon, the Oathsworn',),
('Feather, the Redeemed',),
('Savage Knuckleblade',),
('Harness the Storm',),
('Bedeck',),
('Archon of the Triumvirate',),
('Duskmantle Seer',),
('Jarad, Golgari Lich Lord',),
('Solemn Recruit',),
('Ojutai, Soul of Winter',),
("Liliana, Death's Majesty",),
('Eater of Hope',),
('Engulf the Shore',),
('Mirko Vosk, Mind Drinker',),
('Woodland Wanderer',),
('Steam Vents',),
('Collective Brutality',),
('Glorybringer',),
('Realm-Cloaked Giant',),
('Dreamstealer',),
("Thespian's Stage",),
('Avalanche Tusker',),
('Desecration Demon',),
('Gruul Spellbreaker',),
("Wolf of Devil's Breach",),
('Kenrith, the Returned King',),
('Venerated Loxodon',),
('Ajani Unyielding',),
('Torment of Hailfire',),
('Firesong and Sunspeaker',),
('Folio of Fancies',),
('Fell Flagship',),
('Tetzimoc, Primal Death',),
('Skyship Stalker',),
('Sylvan Primordial',),
('Warden',),
('Charming Prince',),
("Hazoret's Undying Fury",),
('Artisan of Forms',),
('Blood Operative',),
('Ready',),
('Scrapheap Scrounger',),
('Breaking',),
('Pharika, God of Affliction',),
('Astral Cornucopia',),
('Multiform Wonder',),
('Revel in Riches',),
('Anafenza, the Foremost',),
('Battle at the Bridge',),
('Whir of Invention',),
('Polymorphous Rush',),
('Westvale Abbey',),
('Yahenni, Undying Partisan',),
('God-Eternal Kefnet',),
('Lovestruck Beast',),
('Chandra, Torch of Defiance',),
('Theater of Horrors',),
('Niv-Mizzet, Dracogenius',),
('Cindervines',),
("Dromoka's Command",),
('Archfiend of Ifnir',),
('Deathgorge Scavenger',),
('Vraska, Regal Gorgon',),
('Sphinx of the Chimes',),
('Vile Redeemer',),
('Citadel Siege',),
("Tamiyo's Journal",),
('Abandoned Sarcophagus',),
('Assembled Alphas',),
('Drowned Catacomb',),
('Council of the Absolute',),
('Dragonlord Kolaghan',),
('Conjured Currency',),
('Oath of Liliana',),
('God-Eternal Oketra',),
('Spirit of the Hunt',),
('Hanweir Garrison',),
('Dawnbringer Charioteers',),
('Dragonscale General',),
('Hour of Devastation',),
('Grim Haruspex',),
("Sunbringer's Touch",),
('Faeburrow Elder',),
('Aligned Hedron Network',),
('Akoum Firebird',),
('Carnival Hellsteed',),
("Atarka's Command",),
('God-Eternal Rhonas',),
('Hanweir Militia Captain',),
('Angelic Captain',),
('March from the Tomb',),
('Eldrazi Obligator',),
('Command the Dreadhorde',),
('Path of Mettle',),
('Dig Through Time',),
('Outpost Siege',),
('Sylvan Awakening',),
('Rakdos, the Showstopper',),
('Jace, Cunning Castaway',),
('Daxos of Meletis',),
('Aryel, Knight of Windgrace',),
('Sage-Eye Avengers',),
('Nissa, Genesis Mage',),
('Goring Ceratops',),
('Bontu the Glorified',),
('Daring Thief',),
('Nezahal, Primal Tide',),
('Taste of Death',),
("Primevals' Glorious Rebirth",),
('Padeem, Consul of Innovation',),
('Temple of Plenty',),
('Fathom Mage',),
('Gideon, Champion of Justice',),
('Gadwick, the Wizened',),
('Chromatic Lantern',),
("Drana's Chosen",),
('Dictate of Karametra',),
('Vault of Catlacan',),
('Geier Reach Bandit',),
('Karn, Scion of Urza',),
('Etali, Primal Storm',),
("Sigarda, Heron's Grace",),
('Setessan Champion',),
('Undergrowth Champion',),
('Retribution of the Ancients',),
('Stormbreath Dragon',),
('Blacklance Paragon',),
('Gideon of the Trials',),
('Doomwake Giant',),
('Vivid Revival',),
('Mission Briefing',),
("River's Rebuke",),
('Thaumatic Compass',),
('Diluvian Primordial',),
('Captive Audience',),
('Nessian Wilds Ravager',),
('Serpentine Spike',),
("Nissa's Encouragement",),
('Mouth',),
('Bounty Agent',),
('Benthic Biomancer',),
('Bruna, the Fading Light',),
('Verdurous Gearhulk',),
('Always Watching',),
('Hidden Dragonslayer',),
('Thousand Winds',),
('Secret Salvage',),
('Concoct',),
('Prairie Stream',),
('Anthousa, Setessan Hero',),
('Flesh',),
('Niv-Mizzet, Parun',),
('Elspeth, Undaunted Hero',),
('Clan Defiance',),
('Djeru, With Eyes Open',),
('Phenax, God of Deception',),
('Flameblade Angel',),
('Noosegraf Mob',),
('Endless One',),
('Ethereal Absolution',),
('Mastery of the Unseen',),
('Flying Crane Technique',),
('Traxos, Scourge of Kroog',),
('Dawn of Hope',),
('Release to the Wind',),
('To the Slaughter',),
('Pyxis of Pandemonium',),
('Boros Reckoner',),
('Huatli, Radiant Champion',),
('Hatchery Spider',),
('Radiant Purge',),
('Deadlock Trap',),
('Daring Archaeologist',),
('Mindwrack Demon',),
('Arlinn, Embraced by the Moon',),
('Dire Fleet Daredevil',),
('Part the Waterveil',),
('Aurelia, Exemplar of Justice',),
('Wildcall',),
('Steam Augury',),
('Gleam of Authority',),
('Jace, Architect of Thought',),
('Anax and Cymede',),
('Boneyard Parley',),
('Hythonia the Cruel',),
('Corrupted Grafstone',),
("Kolaghan, the Storm's Fury",),
('Crater Elemental',),
('Gruesome Slaughter',),
('Ulrich, Uncontested Alpha',),
('Goblin Dark-Dwellers',),
("Karn's Bastion",),
('Comply',),
('Temple Garden',),
('Shrine of the Forsaken Gods',),
('Threat',),
('Prophetic Flamespeaker',),
('Markov Dreadknight',),
('Ulamog, the Ceaseless Hunger',),
('Detention Sphere',),
('Flamerush Rider',),
('Beast Whisperer',),
('Renounce the Guilds',),
('Conduit of Ruin',),
('Teferi, Time Raveler',),
('Angel of Condemnation',),
('Sidisi, Undead Vizier',),
('Sulfur Falls',),
("Lifecrafter's Bestiary",),
('Regal Caracal',),
('Awakening of Vitu-Ghazi',),
('Bygone Bishop',),
('Primal Wellspring',),
('Traverse the Ulvenwald',),
('Tendershoot Dryad',),
('Prism Array',),
("Mind's Dilation",),
("Narset's Reversal",),
('Mob Rule',),
("Dragonlord's Prerogative",),
('The Elderspell',),
('Replicate',),
('Bioessence Hydra',),
('Temple of Malady',),
('Sunscorch Regent',),
('Oathsworn Knight',),
('Epic Experiment',),
('Finale of Eternity',),
('Paradox Engine',),
('Lumbering Falls',),
('Release the Gremlins',),
("Yahenni's Expertise",),
('Commit',),
('Chaos Maw',),
("Urza's Ruinous Blast",),
('Stromkirk Occultist',),
('Samut, Voice of Dissent',),
('Sire of Insanity',)])

# %%
rows=cur.fetchall()
rows=set(rows)-completedcards

# %%
# cur.execute('''CREATE TABLE transactions (id SERIAL PRIMARY KEY, cardname TEXT,price REAL, carddate TEXT, IsFoil BOOLEAN, saletype TEXT, 
#            cardquantity INTEGER, cardspecial TEXT, cardlanguage TEXT, cardcondition TEXT, title TEXT, possiblybad BOOLEAN,isBanned BOOLEAN, shipping REAL);''')

# conn.commit()

# %%
xfun=lambda x:"x"+str(x)
funx=lambda x:str(x)+"x"
titlequantities=list(chain.from_iterable((xfun(x), funx(x)) for x in range(1,11))) #all lowercase
titlekeywords=["promo","expedition","invocation","invention","extended art"]
titlelanguages=['english','korean','japanese','chinese','russian','spanish']
titleconditions=['NM','LP','MP','HP','Mint','Lightly Played','Moderately Played','Heavily Played']

for cardname in rows:
    if cardname is None:
        print(cardname+"NONE")
    else:
        print(cardname)
        url=requests.get('https://www.ebay.com/sch/i.html?_nkw='+cardname[0]+' mtg'+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200')

        rawtext=BeautifulSoup(url.text,'html.parser')
        transactions=rawtext.find_all('div',attrs={"class":"s-item__info clearfix"})
        totalpagenum=len(rawtext.find_all('li',attrs={"class":"x-pagination__li"}))

        if totalpagenum==0:
            totalpagenum=1
        else:
            pass

        for pagenum in range(1,totalpagenum+1):
            url=requests.get('https://www.ebay.com/sch/i.html?_nkw='+cardname[0]+' mtg'+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200&_pgn='+str(pagenum))

            rawtext=BeautifulSoup(url.text,'html.parser')
            transactions=rawtext.find_all('div',attrs={"class":"s-item__info clearfix"})



            for transaction in transactions:
#                 cardname=None
                price=None
                title=None
                carddate=None
                IsFoil=None
                saletype=None
                cardquantity=None
                cardspecial=None
                cardlanguage=None
                cardcondition=None
                shipping=None
                possiblybad=False
                isBanned=False


                if transaction.find_all('h3',attrs={"class":"s-item__title"})[0].string==None or len(transaction.find_all('h3',attrs={"class":"s-item__title"}))==0:
                    possiblybad=True
                    
                else:
                    title=transaction.find_all('h3',attrs={"class":"s-item__title"})[0].string
                    
                    if title.lower().find(cardname[0].lower())==-1:
                        pass
                    else:
                        for quantity in titlequantities:
                            if title.lower().find(quantity.lower())!=-1:
                                quant = re.findall("(\d+)", quantity)
                                cardquantity=quant[0]
                                break

                        IsFoil=title.lower().find("foil")!=-1

                        for keyword in titlekeywords:
                            if title.lower().find(keyword.lower())!=-1:
                                cardspecial=keyword
                                break

                        for language in titlelanguages:
                            if title.lower().find(language.lower())!=-1:
                                cardlanguage=language
                                break

                        for condition in titleconditions:
                            if title.lower().find(condition.lower())!=-1:
                                cardcondition=condition
                                break



                        if len(transaction.find_all('span',attrs={"class":"s-item__ended-date s-item__endedDate"}))==0:
                            possiblybad=True

                        else:
                            carddate=datetime.strptime(transaction.find_all('span',attrs={"class":"s-item__ended-date s-item__endedDate"})[0].string,'%b-%d %H:%M').date()

                            if carddate.month>=2:
                                carddate=carddate.replace(year=2019)
                            else:
                                carddate=carddate.replace(year=2020)





                        if len(transaction.find_all('span',attrs={"class":"POSITIVE"}))==0:
                            possiblybad=True

                        else:
                            price=float(re.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"POSITIVE"})[0].string))
                            positiveprice=str(transaction.find_all('span',attrs={"class":"POSITIVE"})[0])

                            if positiveprice.find('class="POSITIVE"')!=-1:
                                saletype='normal'
                            elif positiveprice.find('class="POSITIVE ITALIC"')!=-1:
                                saletype='italic'
                            else:
                                saletype='BO accepted'
                                
                        
                        if len(transaction.find_all('span',attrs={"class":"s-item__shipping s-item__logisticsCost"}))==0:
                            possiblybad=True

                        elif re.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"s-item__shipping s-item__logisticsCost"})[0].string)=='':
                            pass
                        else:
                            shipping=float(re.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"s-item__shipping s-item__logisticsCost"})[0].string))
                                



                        cur.execute('''INSERT INTO transactions (cardname,price,carddate,IsFoil,saletype,cardquantity,
                        cardspecial,cardlanguage,cardcondition,title,possiblybad,isBanned,shipping) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''',(cardname,price,carddate,IsFoil,saletype,cardquantity,cardspecial,cardlanguage,cardcondition,title,possiblybad,isBanned,shipping))
                        conn.commit()
# Out:
# ('Grind',)
# ('The Gitrog Monster',)
# ('Teferi, Timebender',)
# ('Ulvenwald Observer',)
# ('Dispossess',)
# ('Omnath, Locus of Rage',)
# ('Arbor Colossus',)
# ('Sphinx of Foresight',)
# ("Munda's Vanguard",)
# ('Ashiok, Sculptor of Fears',)
# ('Cruel Reality',)
# ("Avacyn's Judgment",)
# ('Geier Reach Sanitarium',)
# ('Vizier of Many Faces',)
# ('Lightning Runner',)
# ('Renegade Krasis',)
# ('Path of Discovery',)
# ('Silumgar, the Drifting Death',)
# ('Cascading Cataracts',)
# ('Thalia, Heretic Cathar',)
# ('Throne of the God-Pharaoh',)
# ('Labyrinth Champion',)
# ('Dragonlord Ojutai',)
# ('Pestilent Spirit',)
# ('Consuming Aberration',)
# ('Heart-Piercer Manticore',)
# ('Muldrotha, the Gravetide',)
# ('Trait Doctoring',)
# ('Choked Estuary',)
# ('Zurgo Helmsmasher',)
# ('Sage of Hours',)
# ('Linvala, the Preserver',)
# ('Sandwurm Convergence',)
# ('Silverclad Ferocidons',)
# ('Defiant Bloodlord',)
# ('Abolisher of Bloodlines',)
# ('Treasure Cove',)
# ('Massacre Girl',)
# ('Panharmonicon',)
# ("Tezzeret's Betrayal",)
# ('Forgestoker Dragon',)
# ('Hapatra, Vizier of Poisons',)
# ('Metalwork Colossus',)
# ('Trapjaw Tyrant',)
# ('Volatile Rig',)
# ('Widespread Brutality',)
# ('Game Trail',)
# ('Time Wipe',)
# ('Reverent Hunter',)
# ('Colossus of Akros',)
# ('Crafty Cutpurse',)
# ('Sorin, Grim Nemesis',)
# ('Sram, Senior Edificer',)
# ('Paradoxical Outcome',)
# ('Lazav, the Multifarious',)
# ('Authority of the Consuls',)
# ('Ionize',)
# ('Deicide',)
# ('Gilded Lotus',)
# ('Fated Return',)
# ('Abrupt Decay',)
# ('Smoldering Marsh',)
# ('Peacewalker Colossus',)
# ('Deafening Clarion',)
# ('Sarkhan, the Dragonspeaker',)
# ('Liliana, Death Wielder',)
# ('Shamanic Revelation',)
# ('Cut',)
# ('Dream Eater',)
# ('Territorial Gorger',)
# ('Old-Growth Dryads',)
# ('Wildborn Preserver',)
# ('Collected Company',)
# ('Cast Off',)
# ('Bident of Thassa',)
# ("Rakdos's Return",)
# ('Eternal Scourge',)
# ('Deadbridge Chant',)
# ('Prophet of Kruphix',)
# ('Champion of Rhonas',)
# ('Bloodcrazed Paladin',)
# ('Zurgo Bellstriker',)
# ('Ever After',)
# ('Marwyn, the Nurturer',)
# ('Rubblehulk',)
# ('Selfless Spirit',)
# ('Stratus Dancer',)
# ('Vantress Gargoyle',)
# ('Judith, the Scourge Diva',)
# ('Parhelion II',)
# ('Aethertide Whale',)
# ('Call the Gatewatch',)
# ('Silumgar Assassin',)
# ('Awoken Horror',)
# ('Hope of Ghirapur',)
# ('Wildfire Eternal',)
# ('Void Winnower',)
# ('Crackling Doom',)
# ('Prime Speaker Zegana',)
# ('Warden of the First Tree',)
# ("Elspeth, Sun's Champion",)
# ('Revival',)
# ("Rowan's Stalwarts",)
# ('Athreos, Shroud-Veiled',)
# ('Thassa, God of the Sea',)
# ('Honored Hydra',)
# ('Benalish Marshal',)
# ("Bontu's Last Reckoning",)
# ('Robber of the Rich',)
# ('Setessan Tactics',)
# ('Soul Separator',)
# ('Soulflayer',)
# ("Multani, Yavimaya's Avatar",)
# ('Pitiless Horde',)
# ("Witch's Vengeance",)
# ('Profound Journey',)
# ('Precognitive Perception',)
# ('Knight of Autumn',)
# ('Trap Essence',)
# ('Rattlechains',)
# ('Villainous Wealth',)
# ('Fleecemane Lion',)
# ('Absorb',)
# ('Liliana, Dreadhorde General',)
# ('Sorcerous Spyglass',)
# ('Prime Speaker Vannifar',)
# ("Brass's Bounty",)
# ('Mindswipe',)
# ('Ral, Storm Conduit',)
# ('Temporal Trespass',)
# ('Imprisoned in the Moon',)
# ('Overgrown Tomb',)
# ('Uncage the Menagerie',)
# ('Voldaren Pariah',)
# ('Exava, Rakdos Blood Witch',)
# ('Fated Retribution',)
# ('Stone Haven Outfitter',)
# ("Heroes' Podium",)
# ('Fated Conflagration',)
# ('Perplexing Chimera',)
# ('God-Eternal Bontu',)
# ('Electrodominance',)
# ('High Priest of Penance',)
# ('Rekindling Phoenix',)
# ("Rhonas's Last Stand",)
# ('Rootbound Crag',)
# ('Tempest Djinn',)
# ('Drogskol Cavalry',)
# ('Fated Intervention',)
# ("Azor's Gateway",)
# ('Mizzium Mortars',)
# ('Hardened Scales',)
# ('Priest of the Wakening Sun',)
# ('Precinct Captain',)
# ('Greenbelt Rampager',)
# ('Dire Fleet Poisoner',)
# ('Descent of the Dragons',)
# ('Risen Executioner',)
# ('Escape to the Wilds',)
# ('Docent of Perfection',)
# ('Final Iteration',)
# ('The Locust God',)
# ('Heart of Kiran',)
# ('Oath of Kaya',)
# ('Dreadhorde Invasion',)
# ('Amplifire',)
# ('Spirit of the Labyrinth',)
# ('Hypersonic Dragon',)
# ('The Great Henge',)
# ("Kefnet's Last Word",)
# ('Haphazard Bombardment',)
# ('Reality Smasher',)
# ('As Foretold',)
# ('Nahiri, the Harbinger',)
# ('Gladehart Cavalry',)
# ('Castle Garenbrig',)
# ('Ember Swallower',)
# ('Hero of Iroas',)
# ('Emeria Shepherd',)
# ('Acclaimed Contender',)
# ('Imminent Doom',)
# ('Soul Ransom',)
# ('Biovisionary',)
# ('Polyraptor',)
# ("Oracle's Vault",)
# ('Tolsimir, Friend to Wolves',)
# ('Torrent Elemental',)
# ('Neheb, Dreadhorde Champion',)
# ('Jeskai Ascendancy',)
# ('Siegehorn Ceratops',)
# ('March of the Multitudes',)
# ('Chop Down',)
# ('Samut, the Tested',)
# ('Oath of Jace',)
# ('Mistcutter Hydra',)
# ('Mind Grind',)
# ('The Haunt of Hightower',)
# ('Firedrinker Satyr',)
# ('Ripjaw Raptor',)
# ('Ilharg, the Raze-Boar',)
# ('Living Twister',)
# ('Inspiring Statuary',)
# ('Spear of Heliod',)
# ('Gideon, Martial Paragon',)
# ('Sifter of Skulls',)
# ('Sagu Mauler',)
# ('Ishkanah, Grafwidow',)
# ('Mercurial Chemister',)
# ('Harmonious Archon',)
# ('Regisaur Alpha',)
# ('Blood Crypt',)
# ('Aetherflux Reservoir',)
# ('Hero of Precinct One',)
# ('Dragonlord Atarka',)
# ('Jace, Arcane Strategist',)
# ('Workshop Elders',)
# ('Willing',)
# ('Dreadhorde Butcher',)
# ('Giant Killer',)
# ('Brood Butcher',)
# ('Oracle of Bones',)
# ('Deputy of Detention',)
# ('Silent Submersible',)
# ("Forebear's Blade",)
# ('Dark Intimations',)
# ('Oketra the True',)
# ('Harness by Force',)
# ('Oath of Chandra',)
# ('Induced Amnesia',)
# ('Rampaging Ferocidon',)
# ('Dovin, Grand Arbiter',)
# ('Never',)
# ('Alms Beast',)
# ('Surrak Dragonclaw',)
# ('Persistent Nightmare',)
# ("Vivien's Arkbow",)
# ('Drowner of Hope',)
# ("Jace's Ruse",)
# ('Notion Thief',)
# ('Ruin Raider',)
# ('Zahid, Djinn of the Lamp',)
# ('Blight Herder',)
# ('Harsh Mentor',)
# ('Insidious Mist',)
# ('Ire Shaman',)
# ('Scroll of the Masters',)
# ("Wakening Sun's Avatar",)
# ('Gold-Forge Garrison',)
# ("Sphinx's Decree",)
# ('Glaring Spotlight',)
# ('Tomik, Distinguished Advokist',)
# ('Gilded Goose',)
# ('Castle Vantress',)
# ('Petty Theft',)
# ('Hanweir, the Writhing Township',)
# ('Pack Rat',)
# ('Corpsejack Menace',)
# ('Pontiff of Blight',)
# ('Foul Renewal',)
# ('Descend upon the Sinful',)
# ('Gideon Blackblade',)
# ('Sanctum of the Sun',)
# ('Loxodon Smiter',)
# ('Azor, the Lawbringer',)
# ('Syndicate Trafficker',)
# ('Plaza of Harmony',)
# ("Guildmages' Forum",)
# ('Dragonlord Dromoka',)
# ('Prowling Serpopard',)
# ('Bounty of the Luxa',)
# ('Madcap Experiment',)
# ('Extinguish All Hope',)
# ('Admiral Beckett Brass',)
# ('Chromanticore',)
# ('Sage of the Inward Eye',)
# ('Mirage Mirror',)
# ('Nimble Obstructionist',)
# ("Domri's Nodorog",)
# ('Doom Whisperer',)
# ('Kiora, Master of the Depths',)
# ('Tamiyo, Collector of Tales',)
# ('Fate Unraveler',)
# ('Stormfist Crusader',)
# ('Hostile Desert',)
# ('Rattleclaw Mystic',)
# ('Electrostatic Pummeler',)
# ('Startled Awake',)
# ('Gruul Ragebeast',)
# ('Impetuous Devils',)
# ('Westvale Cult Leader',)
# ('Silverfur Partisan',)
# ('Rageblood Shaman',)
# ('Aid from the Cowl',)
# ('Ashen Rider',)
# ('Merciless Eviction',)
# ('Fevered Visions',)
# ("Kolaghan's Command",)
# ('Connive',)
# ('Rags',)
# ('Spell Swindle',)
# ('Den Protector',)
# ('Legion Warboss',)
# ("Cultivator's Caravan",)
# ("Elspeth, Sun's Nemesis",)
# ('Glass of the Guildpact',)
# ('Spire of Industry',)
# ("Smuggler's Copter",)
# ("Legion's Initiative",)
# ('Aetherwind Basker',)
# ('Iroas, God of Victory',)
# ('Corpseweft',)
# ('From Under the Floorboards',)
# ('Matter Reshaper',)
# ('Aethersphere Harvester',)
# ('Polluted Delta',)
# ('Guardian of Tazeem',)
# ('Verix Bladewing',)
# ('Channeler Initiate',)
# ('Shaman of Forgotten Ways',)
# ('Grove of the Guardian',)
# ("Azor's Elocutors",)
# ('Necromaster Dragon',)
# ('Treasure Map',)
# ('Role Reversal',)
# ('Decimator of the Provinces',)
# ('Deadeye Tracker',)
# ('Mobilized District',)
# ('Freejam Regent',)
# ('Warkite Marauder',)
# ('Sorin, Solemn Visitor',)
# ("Maze's End",)
# ('Godless Shrine',)
# ('Hour of Eternity',)
# ('Priest of Forgotten Gods',)
# ('Zhur-Taa Ancient',)
# ('Soul-Scar Mage',)
# ("Gideon's Battle Cry",)
# ('Siege Rhino',)
# ('Kalitas, Traitor of Ghet',)
# ('Gisela, the Broken Blade',)
# ('Dragonlord Silumgar',)
# ('Wingmate Roc',)
# ('Silverwing Squadron',)
# ('Kaya, Orzhov Usurper',)
# ('Anger of the Gods',)
# ('Rishkar, Peema Renegade',)
# ('Growing Ranks',)
# ('Xenagos, God of Revels',)
# ('Crypt Ghast',)
# ("Captain's Claws",)
# ('Burn from Within',)
# ('Teysa Karlov',)
# ('Agent of the Fates',)
# ('Brimaz, King of Oreskos',)
# ("Dead Man's Chest",)
# ('Itlimoc, Cradle of the Sun',)
# ('Scattered Groves',)
# ('Chandra, Pyrogenius',)
# ('Silent Gravestone',)
# ('Sylvan Advocate',)
# ("Firemind's Research",)
# ('Prized Amalgam',)
# ('Drake Haven',)
# ('Ayli, Eternal Pilgrim',)
# ("Vraska's Scorn",)
# ('Nikya of the Old Ways',)
# ('Keranos, God of Storms',)
# ('Injury',)
# ('Domri Rade',)
# ('Brain in a Jar',)
# ('Simic Manipulator',)
# ('Kheru Lich Lord',)
# ('Lost Legacy',)
# ('Disallow',)
# ('Armada Wurm',)
# ('Angrath, the Flame-Chained',)
# ('Ally Encampment',)
# ('Ashiok, Nightmare Muse',)
# ('Crux of Fate',)
# ('Shimmer Dragon',)
# ('Blind Obedience',)
# ('Believe',)
# ('Font of Agonies',)
# ('Mirror March',)
# ("Chandra's Outburst",)
# ('Paladin of Atonement',)
# ('Master Biomancer',)
# ("Captain's Hook",)
# ('Howl of the Horde',)
# ('Eidolon of Countless Battles',)
# ('Ghirapur Orrery',)
# ('Refuse',)
# ("Liliana's Influence",)
# ('Slaughter the Strong',)
# ('Nullhide Ferox',)
# ('Painful Truths',)
# ("Angrath's Fury",)
# ('Dragon Tempest',)
# ("Kumena's Awakening",)
# ('Sea Gate Wreckage',)
# ('Darigaaz Reincarnated',)
# ('Quasiduplicate',)
# ('Riches',)
# ('Gyre Sage',)
# ('Canopy Vista',)
# ('Bearer of Silence',)
# ('Dragon Throne of Tarkir',)
# ('Hour of Revelation',)
# ('Journey to Eternity',)
# ('Ajani, Mentor of Heroes',)
# ('Pain Seer',)
# ('Dowsing Dagger',)
# ('Angel of Deliverance',)
# ('Wharf Infiltrator',)
# ('Blood Sun',)
# ("Hunter's Prowess",)
# ("Jaya's Immolating Inferno",)
# ('Ignite the Beacon',)
# ('Whisperwood Elemental',)
# ('Varolz, the Scar-Striped',)
# ('Jace, Wielder of Mysteries',)
# ('Borborygmos Enraged',)
# ('Camaraderie',)
# ('Domri, City Smasher',)
# ("Hedonist's Trove",)
# ('Phyrexian Scriptures',)
# ('Majestic Myriarch',)
# ('Daring Saboteur',)
# ('Scourge of Skola Vale',)
# ('Cultivator of Blades',)
# ('Razaketh, the Foulblooded',)
# ("Sunbird's Invocation",)
# ('Blood-Chin Fanatic',)
# ("Knights' Charge",)
# ('Courser of Kruphix',)
# ('Repudiate',)
# ('Hydroid Krasis',)
# ('Shorecrasher Elemental',)
# ('Shambling Vent',)
# ('Protean Raider',)
# ('Sin Prodder',)
# ('Rowan, Fearless Sparkmage',)
# ('Necropolis Regent',)
# ('Felidar Sovereign',)
# ('Ghastly Conscription',)
# ('Living Lore',)
# ('Blood Scrivener',)
# ('Atzal, Cave of Eternity',)
# ('Monastery Siege',)
# ('Plea for Guidance',)
# ('Domri, Chaos Bringer',)
# ('Dynavolt Tower',)
# ('Brisela, Voice of Nightmares',)
# ('Rampage of the Clans',)
# ('Dragon-Style Twins',)
# ('Oath of Nissa',)
# ('Harvest Season',)
# ('Savageborn Hydra',)
# ('Whims of the Fates',)
# ('Sage of Ancient Lore',)
# ('Chaos Imps',)
# ("Mishra's Self-Replicator",)
# ('Boros Battleshaper',)
# ('Fraying Sanity',)
# ('Collective Effort',)
# ('Erratic Cyclops',)
# ('Mana Confluence',)
# ('Foundry Champion',)
# ('Hedron Alignment',)
# ('Dimensional Infiltrator',)
# ('Temur War Shaman',)
# ('Drowned Secrets',)
# ('Reaper of the Wilds',)
# ('Reap Intellect',)
# ('Combustible Gearhulk',)
# ('Akoum Hellkite',)
# ('Rite of Belzenlok',)
# ('Boon Satyr',)
# ('Quicksmith Spy',)
# ('Overwhelming Splendor',)
# ('Squee, the Immortal',)
# ('Abzan Ascendancy',)
# ('Canyon Slough',)
# ('Waker of the Wilds',)
# ('Legion Loyalist',)
# ('Ulrich of the Krallenhorde',)
# ("Conqueror's Galleon",)
# ('Bedazzle',)
# ('Master of Cruelties',)
# ('Arcbond',)
# ('The Akroan War',)
# ('Dire Fleet Ravager',)
# ('Icy Blast',)
# ('Winged Temple of Orazca',)
# ('Altered Ego',)
# ('Two-Headed Giant',)
# ('Huatli, Warrior Poet',)
# ('Seraph of the Scales',)
# ('Toolcraft Exemplar',)
# ('Pull from Tomorrow',)
# ('Ravager Wurm',)
# ('Endbringer',)
# ('Mina and Denn, Wildborn',)
# ('Undercity Plague',)
# ('Seafloor Oracle',)
# ('Celestial Archon',)
# ('Satyr Firedancer',)
# ('Isperia, Supreme Judge',)
# ('Sacred Foundry',)
# ('Vraska the Unseen',)
# ("Obzedat's Aid",)
# ('Pristine Skywise',)
# ("Angrath's Marauders",)
# ('Granted',)
# ('Firemane Avenger',)
# ('The Antiquities War',)
# ('Skysovereign, Consul Flagship',)
# ('Architect of the Untamed',)
# ('Sunpetal Grove',)
# ("Stitcher's Graft",)
# ('Sanctum Seeker',)
# ('Exert Influence',)
# ('Soldier of the Pantheon',)
# ('Guild Feud',)
# ('Korvold, Fae-Cursed King',)
# ('Angrath, Minotaur Pirate',)
# ('Exquisite Archangel',)
# ('Form of the Dinosaur',)
# ('Awakened Amalgam',)
# ('Vorel of the Hull Clade',)
# ('Barrage Tyrant',)
# ('Eldrazi Mimic',)
# ('Cyclonic Rift',)
# ('Karn, the Great Creator',)
# ('Unexpected Results',)
# ('Insult',)
# ('Secure the Wastes',)
# ('Questing Beast',)
# ('Mausoleum Wanderer',)
# ('Angel of Sanctions',)
# ('Alesha, Who Smiles at Death',)
# ('Empty the Pits',)
# ('Hooded Hydra',)
# ('Vivien, Champion of the Wilds',)
# ('Dragonskull Summit',)
# ('Obscuring Aether',)
# ('Curse of the Swine',)
# ('Deathrite Shaman',)
# ('Battlefield Thaumaturge',)
# ('Midnight Clock',)
# ('Oath of Gideon',)
# ("Karn's Temporal Sundering",)
# ('Vraska, Scheming Gorgon',)
# ('Finale of Revelation',)
# ('Hundred-Handed One',)
# ('Planar Bridge',)
# ('Gaze of Granite',)
# ('Flame-Wreathed Phoenix',)
# ('Heroic Intervention',)
# ("Mastermind's Acquisition",)
# ('Spirebluff Canal',)
# ('Thing in the Ice',)
# ('Clackbridge Troll',)
# ('Ruric Thar, the Unbowed',)
# ('History of Benalia',)
# ('Haven of the Spirit Dragon',)
# ('The Scarab God',)
# ('Fall of the Titans',)
# ('Worst Fears',)
# ('End-Raze Forerunners',)
# ('Commune with Lava',)
# ('Duneblast',)
# ('Vildin-Pack Alpha',)
# ('Sire of Stagnation',)
# ('Tamiyo, Field Researcher',)
# ('Soul Swallower',)
# ('Herald of Anafenza',)
# ("Crater's Claws",)
# ('Gluttonous Troll',)
# ("Sphinx's Revelation",)
# ("Pia's Revolution",)
# ('Assault Formation',)
# ('Deathmist Raptor',)
# ('Ral, Izzet Viceroy',)
# ('Jace, Unraveler of Secrets',)
# ('Bonecrusher Giant',)
# ('Enter the God-Eternals',)
# ('Irencrag Pyromancer',)
# ('Pyrewild Shaman',)
# ('Karametra, God of Harvests',)
# ('Izoni, Thousand-Eyed',)
# ("Geralf's Masterpiece",)
# ('Temple of Epiphany',)
# ('Munda, Ambush Leader',)
# ("Vona's Hunger",)
# ('Wayward Swordtooth',)
# ('Deadbridge Goliath',)
# ('The Cauldron of Eternity',)
# ('Jori En, Ruin Diver',)
# ('Lotleth Troll',)
# ('Fight',)
# ('Scourge Wolf',)
# ('Gonti, Lord of Luxury',)
# ('Lupine Prototype',)
# ('New Perspectives',)
# ('Single Combat',)
# ('Splendid Reclamation',)
# ('Harbinger of the Hunt',)
# ('Chandra, Fire Artisan',)
# ('Eliminate the Competition',)
# ('Josu Vess, Lich Knight',)
# ('Deflecting Palm',)
# ('Cataclysmic Gearhulk',)
# ('Boltwing Marauder',)
# ('Rashmi, Eternities Crafter',)
# ('Leave',)
# ('Blessed Reincarnation',)
# ('Coax from the Blind Eternities',)
# ('Captain Lannery Storm',)
# ('Thought-Knot Seer',)
# ('Second Harvest',)
# ('Midnight Reaper',)
# ('Angel of Serenity',)
# ("Ajani's Aid",)
# ('Sunken Hollow',)
# ('Star of Extinction',)
# ('Castle Locthwain',)
# ('Mace of the Valiant',)
# ('Behold the Beyond',)
# ('Underworld Connections',)
# ('Flamewake Phoenix',)
# ('Mizzium Tank',)
# ('Avatar of the Resolute',)
# ('Hypnotic Siren',)
# ('Confirm Suspicions',)
# ('Spires of Orazca',)
# ('Godsend',)
# ('Rubblebelt Raiders',)
# ('Memory',)
# ('Jodah, Archmage Eternal',)
# ('Ajani, the Greathearted',)
# ('Athreos, God of Passage',)
# ('Rhonas the Indomitable',)
# ('Ugin, the Spirit Dragon',)
# ('World Breaker',)
# ('Angel of Grace',)
# ('Pithing Needle',)
# ("Death's Presence",)
# ('Shalai, Voice of Plenty',)
# ('Fabled Hero',)
# ('Planar Outburst',)
# ('Expansion',)
# ('Glory-Bound Initiate',)
# ('Concealed Courtyard',)
# ('Bristling Hydra',)
# ('Unbreakable Formation',)
# ('Zetalpa, Primal Dawn',)
# ('Declaration in Stone',)
# ('Neheb, the Eternal',)
# ('Hazoret the Fervent',)
# ('Deathpact Angel',)
# ('Kambal, Consul of Allocation',)
# ('Gift of Immortality',)
# ('Commence the Endgame',)
# ('Sepulchral Primordial',)
# ('Sarkhan Unbroken',)
# ('Oviya Pashiri, Sage Lifecrafter',)
# ('Doom Foretold',)
# ('Finale of Glory',)
# ('Metzali, Tower of Triumph',)
# ('Vizier of the Menagerie',)
# ('Mystic Genesis',)
# ("Legion's Landing",)
# ('Kari Zev, Skyship Raider',)
# ('Incubation Druid',)
# ('Curator of Mysteries',)
# ('Xenagos, the Reveler',)
# ('Glorious End',)
# ('Confiscation Coup',)
# ('Wildest Dreams',)
# ("Teshar, Ancestor's Apostle",)
# ("Vraska's Contempt",)
# ('Torgaar, Famine Incarnate',)
# ('Hydra Broodmaster',)
# ("Baral's Expertise",)
# ('Experimental Frenzy',)
# ('Quicksmith Rebel',)
# ('Tajic, Blade of the Legion',)
# ('Kheru Spellsnatcher',)
# ('Emmara Tandris',)
# ('Sheltered Thicket',)
# ('Storrev, Devkarin Lich',)
# ('Erebos, God of the Dead',)
# ('Nephalia Moondrakes',)
# ('Obzedat, Ghost Council',)
# ('Spitfire Bastion',)
# ('Eldrazi Displacer',)
# ('Nivmagus Elemental',)
# ('Liliana, the Last Hope',)
# ('The Royal Scions',)
# ('Anguished Unmaking',)
# ('Endless Sands',)
# ("Hadana's Climb",)
# ('Inverter of Truth',)
# ('Archfiend of Depravity',)
# ('Oblivion Sower',)
# ('Baral, Chief of Compliance',)
# ('Elenda, the Dusk Rose',)
# ('Whispering Madness',)
# ('Bedevil',)
# ('Approach of the Second Sun',)
# ('Sorin, Vengeful Bloodlord',)
# ('Dovin, Architect of Law',)
# ('Thoughtseize',)
# ('Stolen Identity',)
# ('Summary Dismissal',)
# ('Underrealm Lich',)
# ('Shaman of the Great Hunt',)
# ('Emergency Powers',)

# %%
cur.close()
conn.close()

# %%
re.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"s-item__shipping s-item__logisticsCost"})[0].string)
# Out:
# ''

# %%
transaction.find_alre.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"POSITIVE"})[0].string)l('span',attrs={"class":"s-item__shipping s-item__logisticsCost"})[0].string
# Out:
#   File "<ipython-input-11-9d1289106f47>", line 1
#     transaction.find_alre.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"POSITIVE"})[0].string)l('span',attrs={"class":"s-item__shipping s-item__logisticsCost"})[0].string
#                                                                                                                ^
# SyntaxError: invalid syntax

# %%
re.sub(r'[^\d.]', '', transaction.find_all('span',attrs={"class":"POSITIVE"})[0].string)

# %%
type(rows[0][0])

# %%
#for idx,cardname in enumerate(rows):
    print(cardname[0])

# %%
type(cardname)==NoneType

# %%
cardname is None or type(cardname[0])!=str

# %%
type(cardname[0])

# %%
type(rows[0][0])

# %%
rows[24][0]

# %%
print(rows)

# %%
cardname is None or type(cardname[0])!=str

# %%
pagenum

# %%
'https://www.ebay.com/sch/i.html?_nkw='+cardname[0]+' mtg'+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200'

# %%
'https://www.ebay.com/sch/i.html?_nkw='+cardname[0]+'&rt=nc&LH_Sold=1&LH_Complete=1&_ipg=200&_pgn='+str(pagenum)

# %%
title.lower().find('mtg')

# %%
title

# %%
cardname[0]

# %%
title.lower().find(cardname[0].lower())

# %%
title.lower().find('lalal'.lower())==-1

# %%
carddate=datetime.strptime(transaction.find_all('span',attrs={"class":"s-item__ended-date s-item__endedDate"})[0].string,'%b-%d %H:%M')

# %%
date="Jan-11 11:06"

# %%
print(datetime.strptime(date,'%b-%d %H:%M').date())

# %%
len(rows)
